# %% [markdown]
# <a href="https://colab.research.google.com/github/Shambhavi-Gupta/EDA-on-population_india_census2011/blob/master/population_india_census2011.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import seaborn as sns
import plotly.io as pio
pio.templates.default = "plotly_dark"
sns.set(style="darkgrid")

# %%
df=pd.read_csv('population_india_census2011.csv')

# %%
df.head()
# Out:
#    Sno State / Union Territory  ...                  Density  Gender Ratio
# 0    1           Uttar Pradesh  ...    828/km2 (2,140/sq mi)           912
# 1    2             Maharashtra  ...      365/km2 (950/sq mi)           929
# 2    3                   Bihar  ...  1,102/km2 (2,850/sq mi)           918
# 3    4             West Bengal  ...  1,029/km2 (2,670/sq mi)           953
# 4    5          Madhya Pradesh  ...      236/km2 (610/sq mi)           931
#
# [5 rows x 8 columns]

# %%
df.shape
# Out:
# (36, 8)

# %%
plt.figure(figsize=(10,5))
sns.set(style="whitegrid")
plt.xticks(rotation=90)
sns.barplot(x='State / Union Territory',y='Gender Ratio',data=df)

# %%
pip install plotly_express==0.4.0

# %%
import plotly_express as px
px.bar(df,x='State / Union Territory',y='Gender Ratio')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f84dd5e8-469b-4410-871c-1fa6f5c4dffe" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f84dd5e8-469b-4410-871c-1fa6f5c4dffe")) {
#                     Plotly.newPlot(
#                         'f84dd5e8-469b-4410-871c-1fa6f5c4dffe',
# ...

# %%
px.scatter(df,x='Population',y='Gender Ratio',color='State / Union Territory',size_max=60,hover_name='State / Union Territory')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9cd2d589-9fc3-4fd0-822b-460d12cb58aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9cd2d589-9fc3-4fd0-822b-460d12cb58aa")) {
#                     Plotly.newPlot(
#                         '9cd2d589-9fc3-4fd0-822b-460d12cb58aa',
# ...

# %%
px.bar(df,x='State / Union Territory',y='Population')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9c74c937-2897-4104-b6e5-1776e987bd77" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9c74c937-2897-4104-b6e5-1776e987bd77")) {
#                     Plotly.newPlot(
#                         '9c74c937-2897-4104-b6e5-1776e987bd77',
# ...

# %%
px.scatter(df,x='Urban population',y='Rural population')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="25a62cc7-698f-48f6-99e3-4abd9428b0cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("25a62cc7-698f-48f6-99e3-4abd9428b0cb")) {
#                     Plotly.newPlot(
#                         '25a62cc7-698f-48f6-99e3-4abd9428b0cb',
# ...

# %%
import plotly.graph_objects as go

# %%
import plotly.graph_objects as go

import pandas as pd

# load dataset
df = pd.read_csv("population_india_census2011.csv")

# create figure
fig = go.Figure()

# Add surface trace
fig.add_trace(go.Surface(z=df.values.tolist(), colorscale="Viridis"))

# Update plot sizing
fig.update_layout(
    width=800,
    height=900,
    autosize=False,
    margin=dict(t=0, b=0, l=0, r=0),
    template="plotly_white",
)

# Update 3D scene options
fig.update_scenes(
    aspectratio=dict(x=1, y=1, z=0.7),
    aspectmode="manual"
)

# Add dropdown
fig.update_layout(
    updatemenus=[
        dict(
            buttons=list([
                dict(
                    args=["type", "surface"],
                    label="3D Surface",
                    method="restyle"
                ),
                dict(
                    args=["type", "heatmap"],
                    label="Heatmap",
                    method="restyle"
                )
            ]),
            direction="down",
            pad={"r": 10, "t": 10},
            showactive=True,
            x=0.1,
            xanchor="left",
            y=1.1,
            yanchor="top"
        ),
    ]
)

# Add annotation
fig.update_layout(
    annotations=[
        dict(text="Trace type:", showarrow=False,
        x=0, y=1.085, yref="paper", align="left")
    ]
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9d04dacb-4119-46ec-a403-0daa50de4114" class="plotly-graph-div" style="height:900px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9d04dacb-4119-46ec-a403-0daa50de4114")) {
#                     Plotly.newPlot(
#                         '9d04dacb-4119-46ec-a403-0daa50de4114',
# ...

# %%
import plotly.express as px

import pandas as pd
df = pd.read_csv('population_india_census2011.csv')

fig = px.line(df, x='State / Union Territory', y='Urban population')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="76173362-37ab-415e-81d1-396f827e23b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("76173362-37ab-415e-81d1-396f827e23b8")) {
#                     Plotly.newPlot(
#                         '76173362-37ab-415e-81d1-396f827e23b8',
# ...

# %%
import plotly.graph_objects as go

import pandas as pd
df = pd.read_csv('population_india_census2011.csv')

fig = go.Figure([go.Scatter(x=df['State / Union Territory'], y=df['Rural population'])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="bfefbadb-fa59-4fee-8697-a4c10f6662d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bfefbadb-fa59-4fee-8697-a4c10f6662d1")) {
#                     Plotly.newPlot(
#                         'bfefbadb-fa59-4fee-8697-a4c10f6662d1',
# ...

# %%
import plotly.graph_objects as go
import pandas as pd
df = pd.read_csv('population_india_census2011.csv')

fig = px.line(df, x='State / Union Territory', y='Population')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3a2e79ab-2276-4e25-9fa5-4a5738b39f54" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3a2e79ab-2276-4e25-9fa5-4a5738b39f54")) {
#                     Plotly.newPlot(
#                         '3a2e79ab-2276-4e25-9fa5-4a5738b39f54',
# ...

# %%
fig= px.scatter(data_frame = df, x='Urban population', y='Gender Ratio', size ='Population' , 
                 color = 'State / Union Territory', hover_name='State / Union Territory',log_x=1, size_max=100)
fig.update_layout(title=' Bubble Chart ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="baa86e8a-d499-4ace-8722-73061b8e9338" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("baa86e8a-d499-4ace-8722-73061b8e9338")) {
#                     Plotly.newPlot(
#                         'baa86e8a-d499-4ace-8722-73061b8e9338',
# ...
